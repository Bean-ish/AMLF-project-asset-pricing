# %%
import pandas as pd
import numpy as np
import pickle

# %%
# for each bin
#     for each feature:
#         generate ale plot of different time color coded

# 9*3 = 27 plots

# %%
alemtx = pd.read_pickle('alemtx.pkl')
mappingx = pd.read_pickle('plottingxmtx.pkl')

# %%
# feature1_list = ["feature1" for _ in range(num_times)]
# feature2_list = ["feature2" for _ in range(num_times)]
# feature3_list = ["feature3" for _ in range(num_times)]

# %% [markdown]
# ### plotting - model 1, bin1

# %%
ale1 = alemtx[0]
mapping1 = mappingx[0]

# %%
# model 1
# for bin 1
# bin 1 feature 1

data1 = {
    'x': ale1[0][0],
    'y': mapping1[0][0]
}

# %%
# model 1
# for bin 2
# bin 2 feature 1

data2 = {
    'x': ale1[1][0],
    'y': mapping1[1][0]
}

# %%
# model 1
# for bin 3
# bin 3 feature 1

data3 = {
    'x': ale1[2][0],
    'y': mapping1[2][0]
}

# %%
# model 1
# for bin 4
# bin 4 feature 1

data4 = {
    'x': ale1[3][0],
    'y': mapping1[3][0]
}

# %%
# model 1
# for bin 5
# bin 5 feature 1

data5 = {
    'x': ale1[4][0],
    'y': mapping1[4][0]
}

# %%
# model 1
# for bin 6
# bin 6 feature 1

data6 = {
    'x': ale1[5][0],
    'y': mapping1[5][0]
}

# %%
# model 1
# for bin 4
# bin 7 feature 1

data7 = {
    'x': ale1[6][0],
    'y': mapping1[6][0]
}

# %%
# model 1
# for bin 4
# bin 8 feature 1

data8 = {
    'x': ale1[7][0],
    'y': mapping1[7][0]
}

# %%
# model 1
# for bin 4
# bin 9 feature 1

data9 = {
    'x': ale1[8][0],
    'y': mapping1[8][0]
}

# %%
import matplotlib.pyplot as plt

data1 = pd.DataFrame(data1).sort_values(by='x')
data2 = pd.DataFrame(data2).sort_values(by='x')
data3 = pd.DataFrame(data3).sort_values(by='x')
data4 = pd.DataFrame(data4).sort_values(by='x')
data5 = pd.DataFrame(data5).sort_values(by='x')
data6 = pd.DataFrame(data6).sort_values(by='x')
data7 = pd.DataFrame(data7).sort_values(by='x')
data8 = pd.DataFrame(data8).sort_values(by='x')
data9 = pd.DataFrame(data9).sort_values(by='x')

# %%
plt.figure(figsize=(25, 8))
labels = ['Agriculture, forestry and fishing','Mining','Construction','Manufacturing',
        'Transportation and public utilities','Wholesale trade','Retail trade','Finance, insurance and real estate',
        'Services']

for i, df in enumerate([data1, data2, data3, data4, data5, data6, data7, data8, data9]):
    plt.plot(df['x'].tolist(), df['y'].tolist(), linestyle='-', label=labels[i])

# Add labels and title
plt.axvline(0, color='black', linestyle='--', linewidth=1.0)

plt.xlabel('dolvol value')
plt.ylabel('ALE value')
plt.title('Graph of ale value of feature dolvol for model 1')
plt.legend()

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.grid(True, linestyle='--', alpha=0.5)

plt.show()
